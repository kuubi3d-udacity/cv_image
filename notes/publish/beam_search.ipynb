# %%
from numpy import array


# Uses a beam to search through the tree
def beam_search(distances, beta):
    # Defines an initial, dummy record structure represented by
    # visited vertices and the path length (so far),
    # traversed along each path.
    paths_so_far = [[list(), 0]]
    
    
    # Propagates through the neighbouring vertices tier by tier
    # (row by row). A vertex position is indicated by its
    # index in each row (dists).
    for idx, tier in enumerate(distances):
        print('idx', idx, ' |  tier weights',tier)
        if idx > 0:
            print(f'Paths kept after tier {idx-1}:')
            print(*paths_so_far, sep='\n')
        paths_at_tier = list()

        
        # Follows each path.
        for i in range(len(paths_so_far)):
            print("path_so_far, length", len(paths_so_far), paths_so_far)
            # Reads the current path and its length (sum of distances).
            path, distance = paths_so_far[i]
            
            # Extends the path for every possible neighboring vertex
            # at the current tier.
            for j in range(len(tier)):
                path_extended = [path + [j], distance + tier[j]]
                print("path=", path,  "path+j=", path + [j])
                print("weight=", distance, "weight + tier[j]=" , distance + tier[j])

                paths_at_tier.append(path_extended)
                print('paths_at_tier', paths_at_tier)
                
        # Sorts the newly generated paths by their length.
        paths_ordered = sorted(paths_at_tier, key=lambda element: element[1])
        
        # The best 'beta' paths are preserved.
        paths_so_far = paths_ordered[:beta]
        print(f'\nPaths pruned after tier {idx}: ')
        print(*paths_ordered[beta:], sep='\n')
        
    return paths_so_far


# Define a distance matrix of 10 tiers
dists = [[1, 3, 2, 5, 8],
         [4, 7, 9, 6, 7]]
dists = array(dists)
print ('weights', dists)

# Calculates the best paths by applying a beam of width 'beta'.
best_beta_paths = beam_search(dists, 3)
print ('best_beta_paths', best_beta_paths)

# Prints the best 'beta' paths.
print('\nThe best \'beta\' paths:')
for beta_path in best_beta_paths:
    print(beta_path)
# Out:
# weights [[1 3 2 5 8]
#  [4 7 9 6 7]]
# idx 0  |  tier weights [1 3 2 5 8]
# path_so_far, length 1 [[[], 0]]
# path= [] path+j= [0]
# weight= 0 weight + tier[j]= 1
# paths_at_tier [[[0], 1]]
# path= [] path+j= [1]
# weight= 0 weight + tier[j]= 3
# paths_at_tier [[[0], 1], [[1], 3]]
# path= [] path+j= [2]
# weight= 0 weight + tier[j]= 2
# paths_at_tier [[[0], 1], [[1], 3], [[2], 2]]
# path= [] path+j= [3]
# weight= 0 weight + tier[j]= 5
# paths_at_tier [[[0], 1], [[1], 3], [[2], 2], [[3], 5]]
# path= [] path+j= [4]
# weight= 0 weight + tier[j]= 8
# paths_at_tier [[[0], 1], [[1], 3], [[2], 2], [[3], 5], [[4], 8]]
#
# Paths pruned after tier 0:
# [[3], 5]
# [[4], 8]
# idx 1  |  tier weights [4 7 9 6 7]
# Paths kept after tier 0:
# [[0], 1]
# [[2], 2]
# [[1], 3]
# path_so_far, length 3 [[[0], 1], [[2], 2], [[1], 3]]
# path= [0] path+j= [0, 0]
# weight= 1 weight + tier[j]= 5
# paths_at_tier [[[0, 0], 5]]
# path= [0] path+j= [0, 1]
# weight= 1 weight + tier[j]= 8
# paths_at_tier [[[0, 0], 5], [[0, 1], 8]]
# path= [0] path+j= [0, 2]
# weight= 1 weight + tier[j]= 10
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10]]
# path= [0] path+j= [0, 3]
# weight= 1 weight + tier[j]= 7
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7]]
# path= [0] path+j= [0, 4]
# weight= 1 weight + tier[j]= 8
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8]]
# path_so_far, length 3 [[[0], 1], [[2], 2], [[1], 3]]
# path= [2] path+j= [2, 0]
# weight= 2 weight + tier[j]= 6
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6]]
# path= [2] path+j= [2, 1]
# weight= 2 weight + tier[j]= 9
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6], [[2, 1], 9]]
# path= [2] path+j= [2, 2]
# weight= 2 weight + tier[j]= 11
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6], [[2, 1], 9], [[2, 2], 11]]
# path= [2] path+j= [2, 3]
# weight= 2 weight + tier[j]= 8
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6], [[2, 1], 9], [[2, 2], 11], [[2, 3], 8]]
# path= [2] path+j= [2, 4]
# weight= 2 weight + tier[j]= 9
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6], [[2, 1], 9], [[2, 2], 11], [[2, 3], 8], [[2, 4], 9]]
# path_so_far, length 3 [[[0], 1], [[2], 2], [[1], 3]]
# path= [1] path+j= [1, 0]
# weight= 3 weight + tier[j]= 7
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6], [[2, 1], 9], [[2, 2], 11], [[2, 3], 8], [[2, 4], 9], [[1, 0], 7]]
# path= [1] path+j= [1, 1]
# weight= 3 weight + tier[j]= 10
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6], [[2, 1], 9], [[2, 2], 11], [[2, 3], 8], [[2, 4], 9], [[1, 0], 7], [[1, 1], 10]]
# path= [1] path+j= [1, 2]
# weight= 3 weight + tier[j]= 12
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6], [[2, 1], 9], [[2, 2], 11], [[2, 3], 8], [[2, 4], 9], [[1, 0], 7], [[1, 1], 10], [[1, 2], 12]]
# path= [1] path+j= [1, 3]
# weight= 3 weight + tier[j]= 9
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6], [[2, 1], 9], [[2, 2], 11], [[2, 3], 8], [[2, 4], 9], [[1, 0], 7], [[1, 1], 10], [[1, 2], 12], [[1, 3], 9]]
# path= [1] path+j= [1, 4]
# weight= 3 weight + tier[j]= 10
# paths_at_tier [[[0, 0], 5], [[0, 1], 8], [[0, 2], 10], [[0, 3], 7], [[0, 4], 8], [[2, 0], 6], [[2, 1], 9], [[2, 2], 11], [[2, 3], 8], [[2, 4], 9], [[1, 0], 7], [[1, 1], 10], [[1, 2], 12], [[1, 3], 9], [[1, 4], 10]]
#
# Paths pruned after tier 1:
# [[1, 0], 7]
# [[0, 1], 8]
# [[0, 4], 8]
# [[2, 3], 8]
# [[2, 1], 9]
# [[2, 4], 9]
# [[1, 3], 9]
# [[0, 2], 10]
# [[1, 1], 10]
# [[1, 4], 10]
# [[2, 2], 11]
# [[1, 2], 12]
# best_beta_paths [[[0, 0], 5], [[2, 0], 6], [[0, 3], 7]]
#
# The best 'beta' paths:
# [[0, 0], 5]
# [[2, 0], 6]
# [[0, 3], 7]
